# %% [markdown]
# # LAB 4

# %% [markdown]
# **Objective:** In this lab we will look to complete our frontend by adding more HTML, bootstrap and CSS. We will also go through everything we have done so far.
#
# **Current Problem:** Currently the frontend looks poor and requires work.
#
# **Solution:** We will use HTML with Django codeblocks, boostrap and CSS to finish our front end completely (for now).

# %% [markdown]
# ## Step 1 Complete base template

# %% [markdown]
# **Overview:** The code below will be everything required to complete the base template.
#
# Question: What is the base template?
#
# **A)** Copy and paste code below.
#
# Note: The HTML code seems intimidating but we will be doing a breakdown of the code during the session.

# %%
<!DOCTYPE html>
<html>
<head>

    <!-- Required meta tags -->
    <meta charset="utf-8">
    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">

    <!-- Bootstrap CSS -->
    <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">

    {% if title %}
        <title>Django Blog - {{ title }}</title>
    {% else %}
        <title>Django Blog</title>
    {% endif %}
</head>
<body>
    <header class="site-header">
      <nav class="navbar navbar-expand-md navbar-dark bg-steel fixed-top">
        <div class="container">
          <a class="navbar-brand mr-4" href="{% url 'blog-home' %}">Django Blog</a>
          <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarToggle" aria-controls="navbarToggle" aria-expanded="false" aria-label="Toggle navigation">
          <span class="navbar-toggler-icon"></span>
          </button>
          <div class="collapse navbar-collapse" id="navbarToggle">
            <div class="navbar-nav mr-auto">
              <a class="nav-item nav-link" href="{% url 'blog-home' %}">Home</a>
              <a class="nav-item nav-link" href="{% url 'blog-about' %}">About</a>
            </div>
            <!-- Navbar Right Side -->
            <div class="navbar-nav">
              <a class="nav-item nav-link" href="#">Login</a>
              <a class="nav-item nav-link" href="#">Register</a>
            </div>
          </div>
        </div>
      </nav>
    </header>
    <main role="main" class="container">
      <div class="row">
        <div class="col-md-8">
          {% block content %}{% endblock %}
        </div>
        <div class="col-md-4">
          <div class="content-section">
            <h3>Our Sidebar</h3>
            <p class='text-muted'>You can put any information here you'd like.
              <ul class="list-group">
                <li class="list-group-item list-group-item-light">Latest Posts</li>
                <li class="list-group-item list-group-item-light">Announcements</li>
                <li class="list-group-item list-group-item-light">Calendars</li>
                <li class="list-group-item list-group-item-light">etc</li>
              </ul>
            </p>
          </div>
        </div>
      </div>
    </main>

    <!-- Optional JavaScript -->
    <!-- jQuery first, then Popper.js, then Bootstrap JS -->
    <script src="https://code.jquery.com/jquery-3.2.1.slim.min.js" integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN" crossorigin="anonymous"></script>
    <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js" integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" crossorigin="anonymous"></script>
    <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" crossorigin="anonymous"></script>
</body>
</html>

# %% [markdown]
# ## Step 2 Complete home.html and about.html

# %% [markdown]
# **Overview:** The code below contains many things we are yet to understand. However, observe the django code block tags. What do you think they do/refer to?

# %%
{% extends "blog/base.html" %}
{% block content %}
    {% for post in posts %}
        <article class="media content-section">
          <div class="media-body">
            <div class="article-metadata">
              <a class="mr-2" href="#">{{ post.author }}</a>
              <small class="text-muted">{{ post.date_posted }}</small>
            </div>
            <h2><a class="article-title" href="#">{{ post.title }}</a></h2>
            <p class="article-content">{{ post.content }}</p>
          </div>
        </article>
    {% endfor %}
{% endblock content %}

# %% [markdown]
# **A)** about.html copy paste. No significant changes

# %%
{% extends "blog/base.html" %}
{% block content %}
    <h1>About Page</h1>
{% endblock content %}

# %% [markdown]
# ## Step 3 Dummy Data

# %% [markdown]
# **Overview**: Lets now add some dummy data that will act as blog posts. Of course we will be using databases to house this information later on (next lab) but for now we just want to have some data that the home.html tags can refer to.
#
# **A)** Copy and paste this code into the top of blog/view.py file.

# %%
posts = [
    {
        'author': 'CoreyMS',
        'title': 'Blog Post 1',
        'content': 'First post content',
        'date_posted': 'August 27, 2018'
    },
    {
        'author': 'Jane Doe',
        'title': 'Blog Post 2',
        'content': 'Second post content',
        'date_posted': 'August 28, 2018'
    }
]

# %% [markdown]
# **B)** What does this code look like? What data structure is this? Can you describe what is being shown and how does it link to the html page? Where have we seen post before?
#
# **NOTE: IF YOU HAVE BEEN PAYING ATTENTION AND ACTUALLY LOOKED AT THE HOME.HTML FILE AS REQUESTED YOU WILL SEE THAT THE DJANGO CODE BLOCKS HAVE THE EXACT SAME NAME HEADERS AS THIS DATA.**
#
# **C)** Once again, please refer to the django documentation to understand what these code blocks do.
#
# **D)** Update the rest of your views.py file with this code.

# %%
def home(request):
    context = {
        'posts': posts
    }
    return render(request, 'blog/home.html', context)


def about(request):
    return render(request, 'blog/about.html', {'title': 'About'})

# %% [markdown]
# ## Step 4 Adding CSS

# %% [markdown]
# **Overview**: Now we are going to add some CSS to our base template. Your are probably wondering what is css? Why do we need it for our project? How will we implement it? How will we connect the css file to our base HTML file? Will the css be inherited to all other pages also?
#
# These are the questions we will be exploring in this step.
#
# **A)** What is CSS? Please refer to the link below
# https://www.w3schools.com/css/css_intro.asp
#
# **B)** Why do we need it for our project?
# We dont HAVE to include it, however as previously explained it nice to learn using a clean frontend so we can easliy visulise changes we make.
#
# **C)** How will we implement this?
# We first create a folder called 'static' in our blog root directory. This folder will house our static files such as css. Similarly to templates, django by default looks for files called static. But what are django static files?
#
# Aside from the HTML generated by the server, web applications generally need to serve additional files — such as images, JavaScript, or CSS — necessary to render the complete web page. In Django, we refer to these files as **“static files”.**
#
# --------------------------------------------------------------------
#
# *Your directory should look something similar to this:*
#
# **blog -> static -> blog -> main.css**
#
# **C)** Inside your main.css file copy and paste the code below.

# %%
  
body {
  background: #fafafa;
  color: #333333;
  margin-top: 5rem;
}

h1, h2, h3, h4, h5, h6 {
  color: #444444;
}

ul {
  margin: 0;
}

.bg-steel {
  background-color: #5f788a;
}

.site-header .navbar-nav .nav-link {
  color: #cbd5db;
}

.site-header .navbar-nav .nav-link:hover {
  color: #ffffff;
}

.site-header .navbar-nav .nav-link.active {
  font-weight: 500;
}

.content-section {
  background: #ffffff;
  padding: 10px 20px;
  border: 1px solid #dddddd;
  border-radius: 3px;
  margin-bottom: 20px;
}

.article-title {
  color: #444444;
}

a.article-title:hover {
  color: #428bca;
  text-decoration: none;
}

.article-content {
  white-space: pre-line;
}

.article-img {
  height: 65px;
  width: 65px;
  margin-right: 16px;
}

.article-metadata {
  padding-bottom: 1px;
  margin-bottom: 4px;
  border-bottom: 1px solid #e3e3e3
}

.article-metadata a:hover {
  color: #333;
  text-decoration: none;
}

.article-svg {
  width: 25px;
  height: 25px;
  vertical-align: middle;
}

.account-img {
  height: 125px;
  width: 125px;
  margin-right: 20px;
  margin-bottom: 16px;
}

.account-heading {
  font-size: 2.5rem;
}

# %% [markdown]
# **Note:** Have a look at this code. Is there anything you recognise from HTML? In general what do you think it controls?
#
# **HINT: SIMPLY READ WHAT IS THERE THE ANSWER IS IN THE CODE!**

# %% [markdown]
# **D)** How will be connect our CSS file to our base HTML template file?
# Currently the base file is not using the static CSS file we have just created since there is no code in the base.html file that prompts it to point to that code. We will look to fix this now.
#
# First copy and paste the code below AT THE TOP of the base.html file.
#
# What do you think it does?

# %%
{% load static %}
#Load static file

# %% [markdown]
# **D)** Now copy and paste the code block below inside your main head tag.

# %%
<link rel="stylesheet" type="text/css" href="{% static 'blog/main.css' %}"> 
#Load CSS file from the static directory.

# %% [markdown]
# What do you think it does?
#
# **E)** Will all other files inherit this CSS?
# Lets check now. Run your server and have a look.
# What do you observe? Why do you think that is the case?
#
# Now have a play around changing the styles in the main.css style sheet. Refer to the documentation linked above to find out more about what you are changing.

# %% [markdown]
# ## Step 5 More base.html

# %% [markdown]
# **Overview:** We previously copy a pasted a large amount of code into our base.html file which we may not have understood. We will look at some key areas now.
#
# **A)** Have a look at the codeblock below.

# %%
              <a class="nav-item nav-link" href="{% url 'blog-home' %}">Home</a>
              <a class="nav-item nav-link" href="{% url 'blog-about' %}">About</a>

# %% [markdown]
# What do you notice about it? Have a look at blog/urls.py. What do you notice? Is there a link between these lines of code and what is in urls.py?
#
# **HINT: ONCE AGAIN JUST LOOK AT IT PROPERLY AND YOU WILL BE ABLE TO TELL ALOT ABOUT WHAT IT DOES. IF YOU DONT HAVE AN ANSWER THEN YOU ARNT USING YOUR EYES OR BRAIN AT ALL AND NEED TO SLEEP OR REST UP. THE ANSWER DOSENT HAVE TO BE RIGHT BUT YOU MUST SAY SOMETHING OF VALUE.**

# %% [markdown]
# Note: Please refer to the documentation. CTRL F URL and read what is written.
# https://docs.djangoproject.com/en/3.2/ref/templates/builtins/
#
# **A)** The way this has been implemented is super efficient compared to the standard way.
