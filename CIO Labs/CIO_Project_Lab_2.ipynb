# %% [markdown]
# # LAB 2

# %% [markdown]
# **Objective**: In this lab we will be looking to organise and improve our frontend (what the user sees) using templates. We will also allow for our server to request these pages.
#
# **Current Problem**: Currently we have html code embedded into functions in our views.py file. While this is great for initial testing of our server, the html code we are looking to implement will be much more robust. Additionally the way we have currently implimented our HTML means that we must repeat code for each function.
#
# **Solution**:
# Hence we will look to create a new folder containing all pages the user will view and interact with.

# %% [markdown]
# ## Step 1: Create directory + VSCODE

# %% [markdown]
# **A)** Inside our blog app directory right click and add a folder called 'Templates'

# %% [markdown]
# **B)** By default Django looks for a template files within the apps connected.
#
# **blog -> templates -> blog -> template.html**
#
# Now within the templates folder, add a new file called home.html and about.html.

# %% [markdown]
# *If you encounter any problems here we may have to move our project to a editor like VSCODE.*

# %% [markdown]
# **C)** Actually we should probably move our project to VSCODE. Click the link below and install the editor.
#
# https://code.visualstudio.com/download

# %% [markdown]
# **D)** Setup project again in VSCODE using the same steps

# %% [markdown]
# ## Step 2: HTML Code

# %% [markdown]
# **A)** Copy and paste the code below into you home.hmtl file.

# %% [markdown]
# ```
# <!DOCTYPE html>
# <html>
# <head>
#   <title></title>
# </head>
# <body>
#   <h1> Blog home! </h1>
# </body>
# </html>
# ```

# %% [markdown]
# **B)** Let quickly try to understand our HTML code. Please refer to the link below.
#
# https://www.w3schools.com/html/html_basic.asp

# %% [markdown]
# ## Step 3: Connect our app to Django

# %% [markdown]
# **Overview:** As we previously explained Django automatically searchs for folders named *'template*'. However it can only searched in apps which are connected to it.
#
# In this section we will be doing just that; connecting our app to Django. This will allow it to find out templates folder and access our HTML files.

# %% [markdown]
# **A)** First we need to find what our App class is. To find this go to blog/apps.py. The name of the class should be BlogConfig. Copy this class name.

# %% [markdown]
# **B)** Now lets connect it to django. Go into to django_project/settings.py. Scroll until you find a variable storing an array of strings called INSTALLED_APPS. Now we add our file path to the top of the list. *'blog.apps.BlogConfig',*  (Make sure to add the coma at the end!!!).
#
# **Note**: *Everytime we create a new application you must connect it to the django apps list.*

# %% [markdown]
# ## Step 4: Render our views

# %% [markdown]
# **Overview:** Now we want to be able to see the HTML code we have written for our specific endpoint.
#
# Before you see the answers below, what file/s do you think we will need to edit?
#
# Add a markdown with the answer below.

# %% [markdown]
# A) Go into your views.py file and insert the following code.

# %%
def home(request): 
  return render(request, 'blog/home.html') #The render function accepts the request method and the template file. 

  #Note: Render still returns a http response!
